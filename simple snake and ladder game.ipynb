# %%
import random
y=0
z=0

k=0
while k==0:
    
    a=input("ply1: enter anything to roll:  ")
    p1=random.choice([1,2,3,4,5,6])
    print("you rolled", p1)
    
  
    
    
    if y==0 and p1==6:
        
        y=y+1
        print("your position", y)
    
        
    elif y>=1:
                        
        y=y+p1
        print("your position", y)
        
        if y>=100:
            
            print("YOU WON")
            break
        elif y==11 or y==20 or y==27 or y==34 or y==61 or y==69 or y==75 or y==85 or y==91 :
            
            y=y+9
            print("you got ladder and your position", y)
        elif y==23 or y==45 or y==72 or y==89:
            y=y-5
            print("sanke bite you and your position",y)
    
    
    
    else:
        y=0
                           
            
    b=input("ply2: enter anything to roll:  ")
    p2=random.choice([1,2,3,4,5,6])
    print("you rolled",p2)
    
    

    if z==0 and p2==6:
                
        z=z+1
        print("your position", z)
     


    elif z>=1:        
        
        z=z+p2
        print("your position", z)
        
        if z>=100:

            print("YOU WON")
            break
                
        elif z==20 or z==27 or z==34 or z==61 or z==69 or z==75 or z==85 or z==91:
            
            z=z+9
            print("you got ladder and your position", z)
        elif z==23 or z==45 or z==72 or z==89:
            z=z-5
            print("sanke bite you and your position",z)
       
                
    

                      


    else :
        z=0
# Out:
# ply1: enter anything to roll:
# you rolled 6
# your position 1
# ply2: enter anything to roll:
# you rolled 3
# ply1: enter anything to roll:
# you rolled 1
# your position 2
# ply2: enter anything to roll:
# you rolled 2
# ply1: enter anything to roll:
# you rolled 4
# your position 6
# ply2: enter anything to roll:
# you rolled 3
# ply1: enter anything to roll:
# you rolled 2
# your position 8
# ply2: enter anything to roll:
# you rolled 3
# ply1: enter anything to roll:
# you rolled 1
# your position 9
# ply2: enter anything to roll:
# you rolled 6
# your position 1
# ply1: enter anything to roll:
# you rolled 6
# your position 15
# ply2: enter anything to roll:
# you rolled 4
# your position 5
# ply1: enter anything to roll:
# you rolled 1
# your position 16
# ply2: enter anything to roll:
# you rolled 1
# your position 6
# ply1: enter anything to roll:
# you rolled 6
# your position 22
# ply2: enter anything to roll:
# you rolled 5
# your position 11
# ...
